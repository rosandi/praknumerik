# %% [markdown]
# # Vektor dan Matriks
#
# ## 1. Deklarasi variabel vektor
#
# Berikut adalah data vektor,
#
# 1. ${\bf a} = 2\hat i + 3\hat j + \hat k$
# 2. ${\bf b} = 5\hat i + 4\hat j - 2\hat k$
# 3. ${\bf c} = 4\hat i + 2\hat j + 3\hat k$
# 4. ${\bf d} = \hat i + \hat j - 3\hat k$
# 5. ${\bf e} = 6\hat i + 2\hat j + \hat k$
#
# Deklarasikan vektor-vektor di atas dalam Python **list**.

# %% [markdown]
# ### Menyimpan dan membaca vektor dari file
#
# 1. Buat program untuk menyimpan vektor-vektor diatas dalam file teks mentah (_plain text_).
# 2. Buat pula program untuk membaca vektor-vektor diatas ke dalam variabel.

# %% [markdown]
# ## 2. Operasi-operasi vektor
#
# Buat fungsi untuk perkalian vektor **tanpa menggunakan** operator perkalian vektor dari numpy.
#
# ### Dot dan cross product
#
# Menggunakan vektor-vektor yang didefinisikan di soal nomor 1, hitung perkalian berikut menggunakan fungsi yang didefinisikan diatas,
#
# 1. ${\bf a \cdot b}$
# 2. ${\bf a \cdot c}$
# 3. ${\bf d \cdot c}$
# 4. ${\bf c \cdot e}$
# 5. ${\bf d \cdot e}$
# 6. ${\bf a \times b}$
# 7. ${\bf b \times a}$
# 8. ${\bf c \times d}$
# 9. ${\bf e \times d}$
# 10. ${\bf c \times e}$
#
# Bandingkan hasilnya dengan menggunakan operator dari numpy, `np.dot()` dan `np.cross()` dan data dideklarikan dalam `np.array()`.

# %% [markdown]
# ### Outer product
#
# Buat pula fungsi untuk melakukan outer product. Hitung outer product untuk yang berikut,
#
# 1. $\bf a \otimes b$
# 2. $\bf b \otimes c$
# 3. $\bf c \otimes d$
# 4. $\bf d \otimes e$
# 5. $\bf e \otimes d$

# %% [markdown]
# ## 3. Deklarasi Matriks
#
# ### ND-Array dalam Python
#
# Buat data matriks berikut,
#
# Matriks 1.
#
# $$
# \left[\begin{matrix}
# 2 & 3 & 2 \\
# 1 & 3 & 3 \\
# 2 & 3 & 6
# \end{matrix}\right]
# $$
#
# Matriks 2.
#
# $$
# \left[\begin{matrix}
# 1 & 4 & 1 \\
# 9 & 1 & 6 \\
# 1 & 7 & 4
# \end{matrix}\right]
# $$
#
# Matriks 3.
#
# $$
# \left[\begin{matrix}
# 2 & 2 & 0 \\
# 9 & 2 & 8 \\
# 6 & 2 & 2
# \end{matrix}\right]
# $$
#
# Matriks 4.
#
# $$
# \left[\begin{matrix}
# 4 & 4 & 6 \\
# 9 & 9 & 7 \\
# 1 & 5 & 2
# \end{matrix}\right]
# $$

# %% [markdown]
# ### Menyimpan dan membaca data matriks
#
# 1. Buat program untuk menyimpan data matriks-matriks diatas dalam file teks.
# 2. Buat program untuk membaca kembali data matriks diatas ke dalam variabel `nd.array`.
# 3. Buat program untuk menyimpan data matriks diatas dalam file `json` menggunakan pustaka.
# 4. Buat program untuk menyimpan data matriks diatas ke dalam _dictionary_.

# %% [markdown]
# ## 4. Operasi-operasi matriks
#
# ### Perkalian vektor dengan matriks
#
# ### Perkalian matriks dengan matriks
#
# ### Trace matriks
#
# ### Norm matriks
#
# ### Menghitung determinan
